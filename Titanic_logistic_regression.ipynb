# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/Users/venka/OneDrive/Desktop/Data science course/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # checking Null values in each column

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# dtype: int64

# %% [markdown]
# - Cabin column as more null values and it is not effecting the dataset we can drop it
# - Age is numerica we have replace null values with mean or median
# - Embarked column is categorical, replace null values with mode

# %%
df.drop(["Cabin"],axis=1,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# - Here mean and median are almost similar we can replace null values with mean or median

# %%
plt.figure(figsize=(10,7))
sns.distplot(df["Age"])
plt.axvline(df["Age"].mean(),color='r')
plt.axvline(df["Age"].median(),color='b')
plt.title("Distplot")
plt.show()
# Out:
# C:\Users\venka\AppData\Local\Temp\ipykernel_10220\1084770446.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Embarked       2
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["Embarked"].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df["Embarked"].mode()[0]
# Out:
# 'S'

# %%
df["Embarked"].fillna(df["Embarked"].mode()[0],inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Feature Engineering
# - Reduce columns as much as possible

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# - Slibsp : sibling or spouse are there or not
# - Parch : parents or child are there or not
# - 2 columns combined as family size
# - family size= slibsp+parch+1( 1 is the person itself)

# %%
df["Famsize"]=df["SibSp"]+df["Parch"]+1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked  Famsize
# 0        1      0         A/5 21171   7.2500        S        2
# 1        1      0          PC 17599  71.2833        C        2
# 2        0      0  STON/O2. 3101282   7.9250        S        1
# 3        1      0            113803  53.1000        S        2
# 4        0      0            373450   8.0500        S        1
# ..     ...    ...               ...      ...      ...      ...
# 886      0      0            211536  13.0000        S        1
# 887      0      0            112053  30.0000        S        1
# 888      1      2        W./C. 6607  23.4500        S        4
# 889      0      0            111369  30.0000        C        1
# 890      0      0            370376   7.7500        Q        1
#
# [891 rows x 12 columns]

# %% [markdown]
# - column called genderclass here i am adding a age<15 as child

# %%
df["GenderClass"]=df["Sex"]
df.loc[df["Age"]<=15,"GenderClass"]="Child"
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked  Famsize GenderClass
# 0        1      0         A/5 21171   7.2500        S        2        male
# 1        1      0          PC 17599  71.2833        C        2      female
# 2        0      0  STON/O2. 3101282   7.9250        S        1      female
# 3        1      0            113803  53.1000        S        2      female
# 4        0      0            373450   8.0500        S        1        male
# ..     ...    ...               ...      ...      ...      ...         ...
# 886      0      0            211536  13.0000        S        1        male
# 887      0      0            112053  30.0000        S        1      female
# 888      1      2        W./C. 6607  23.4500        S        4      female
# 889      0      0            111369  30.0000        C        1        male
# 890      0      0            370376   7.7500        Q        1        male
#
# [891 rows x 13 columns]

# %% [markdown]
# - or we can write with lamda function
# - df[GenderClass]=df.apply(lambda x: "Child" if df["Age"] <15 else df["Sex"], axis=1)

# %%
df.shape
# Out:
# (891, 13)

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - Now drop unwanted columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Famsize GenderClass
# 0      0         A/5 21171   7.2500        S        2        male
# 1      0          PC 17599  71.2833        C        2      female
# 2      0  STON/O2. 3101282   7.9250        S        1      female
# 3      0            113803  53.1000        S        2      female
# 4      0            373450   8.0500        S        1        male

# %%
df.drop(["PassengerId","Name","Sex","SibSp","Parch","Ticket"],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass        Age     Fare Embarked  Famsize GenderClass
# 0           0       3  22.000000   7.2500        S        2        male
# 1           1       1  38.000000  71.2833        C        2      female
# 2           1       3  26.000000   7.9250        S        1      female
# 3           1       1  35.000000  53.1000        S        2      female
# 4           0       3  35.000000   8.0500        S        1        male
# ..        ...     ...        ...      ...      ...      ...         ...
# 886         0       2  27.000000  13.0000        S        1        male
# 887         1       1  19.000000  30.0000        S        1      female
# 888         0       3  29.699118  23.4500        S        4      female
# 889         1       1  26.000000  30.0000        C        1        male
# 890         0       3  32.000000   7.7500        Q        1        male
#
# [891 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'Fare', 'Embarked', 'Famsize',
#        'GenderClass'],
#       dtype='object')

# %% [markdown]
# - Here Gender calss and embarked are categorical we need to convert into numerical
# - Here we are using Dumpification

# %% [markdown]
# # Dummification
# - There are two method
#     - OneHot encoding
#     - Label Encoder

# %%
df=pd.get_dummies(df,columns=["GenderClass","Embarked"],drop_first=True,dtype=int)
df #one hot encoding. For dependent columns always we use one hot encoding
# Out:
#      Survived  Pclass        Age     Fare  Famsize  GenderClass_female  \
# 0           0       3  22.000000   7.2500        2                   0
# 1           1       1  38.000000  71.2833        2                   1
# 2           1       3  26.000000   7.9250        1                   1
# 3           1       1  35.000000  53.1000        2                   1
# 4           0       3  35.000000   8.0500        1                   0
# ..        ...     ...        ...      ...      ...                 ...
# 886         0       2  27.000000  13.0000        1                   0
# 887         1       1  19.000000  30.0000        1                   1
# 888         0       3  29.699118  23.4500        4                   1
# 889         1       1  26.000000  30.0000        1                   0
# 890         0       3  32.000000   7.7500        1                   0
#
#      GenderClass_male  Embarked_Q  Embarked_S
# 0                   1           0           1
# 1                   0           0           0
# 2                   0           0           1
# 3                   0           0           1
# 4                   1           0           1
# ..                ...         ...         ...
# 886                 1           0           1
# 887                 0           0           1
# 888                 0           0           1
# 889                 1           0           0
# 890                 1           1           0
#
# [891 rows x 9 columns]

# %% [markdown]
# # Rename Columns

# %%
df.rename({"GenderClass_female":"GenderClass_Female","GenderClass_male":"GenderClass_Male"},axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass        Age     Fare  Famsize  GenderClass_Female  \
# 0           0       3  22.000000   7.2500        2                   0
# 1           1       1  38.000000  71.2833        2                   1
# 2           1       3  26.000000   7.9250        1                   1
# 3           1       1  35.000000  53.1000        2                   1
# 4           0       3  35.000000   8.0500        1                   0
# ..        ...     ...        ...      ...      ...                 ...
# 886         0       2  27.000000  13.0000        1                   0
# 887         1       1  19.000000  30.0000        1                   1
# 888         0       3  29.699118  23.4500        4                   1
# 889         1       1  26.000000  30.0000        1                   0
# 890         0       3  32.000000   7.7500        1                   0
#
#      GenderClass_Male  Embarked_Q  Embarked_S
# 0                   1           0           1
# 1                   0           0           0
# 2                   0           0           1
# 3                   0           0           1
# 4                   1           0           1
# ..                ...         ...         ...
# 886                 1           0           1
# 887                 0           0           1
# 888                 0           0           1
# 889                 1           0           0
# 890                 1           1           0
#
# [891 rows x 9 columns]

# %%
X=df.iloc[:,df.columns!="Survived"]
X
# Out:
#      Pclass        Age     Fare  Famsize  GenderClass_Female  \
# 0         3  22.000000   7.2500        2                   0
# 1         1  38.000000  71.2833        2                   1
# 2         3  26.000000   7.9250        1                   1
# 3         1  35.000000  53.1000        2                   1
# 4         3  35.000000   8.0500        1                   0
# ..      ...        ...      ...      ...                 ...
# 886       2  27.000000  13.0000        1                   0
# 887       1  19.000000  30.0000        1                   1
# 888       3  29.699118  23.4500        4                   1
# 889       1  26.000000  30.0000        1                   0
# 890       3  32.000000   7.7500        1                   0
#
#      GenderClass_Male  Embarked_Q  Embarked_S
# 0                   1           0           1
# 1                   0           0           0
# 2                   0           0           1
# 3                   0           0           1
# 4                   1           0           1
# ..                ...         ...         ...
# 886                 1           0           1
# 887                 0           0           1
# 888                 0           0           1
# 889                 1           0           0
# 890                 1           1           0
#
# [891 rows x 8 columns]

# %%
y=df["Survived"]
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %% [markdown]
#  - Or we can write
# - y=df[:,0]

# %% [markdown]
# # Splitting into X and y training and test datasets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=750)

# %%
X_train.head()
# Out:
#      Pclass        Age      Fare  Famsize  GenderClass_Female  \
# 428       3  29.699118    7.7500        1                   0
# 248       1  37.000000   52.5542        3                   0
# 118       1  24.000000  247.5208        2                   0
# 326       3  61.000000    6.2375        1                   0
# 369       1  24.000000   69.3000        1                   1
#
#      GenderClass_Male  Embarked_Q  Embarked_S
# 428                 1           1           0
# 248                 1           0           1
# 118                 1           0           0
# 326                 1           0           1
# 369                 0           0           0

# %%
X_test.head()
# Out:
#      Pclass        Age     Fare  Famsize  GenderClass_Female  \
# 626       2  57.000000  12.3500        1                   0
# 672       2  70.000000  10.5000        1                   0
# 246       3  25.000000   7.7750        1                   1
# 173       3  21.000000   7.9250        1                   0
# 601       3  29.699118   7.8958        1                   0
#
#      GenderClass_Male  Embarked_Q  Embarked_S
# 626                 1           1           0
# 672                 1           0           1
# 246                 0           0           1
# 173                 1           0           1
# 601                 1           0           1

# %%
y_train.head()
# Out:
# 428    0
# 248    1
# 118    0
# 326    0
# 369    1
# Name: Survived, dtype: int64

# %%
y_test.head()
# Out:
# 626    0
# 672    0
# 246    0
# 173    0
# 601    0
# Name: Survived, dtype: int64

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (712, 8) (179, 8) (712,) (179,)

# %% [markdown]
# - Here Age and Fare are Numerical columns we need standadise them

# %%
num_col=["Age","Fare"]
num_col
# Out:
# ['Age', 'Fare']

# %% [markdown]
# # standardization
# - We can standardize the numerical columns by 3 ways
#     - MinMax Scaler
#     - Standard Scaler
#     - Robust Scaler

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler
# sc=MinMaxScaler()
# sc=RobustScaler()
sc=StandardScaler()
X_train[num_col]=sc.fit_transform(X_train[num_col])
X_test[num_col]=sc.fit_transform(X_test[num_col])

# %%
X_train.head()
# Out:
#      Pclass       Age      Fare  Famsize  GenderClass_Female  \
# 428       3  0.012850 -0.471358        1                   0
# 248       1  0.578698  0.409214        3                   0
# 118       1 -0.428855  4.241045        2                   0
# 326       3  2.438796 -0.501084        1                   0
# 369       1 -0.428855  0.738332        1                   1
#
#      GenderClass_Male  Embarked_Q  Embarked_S
# 428                 1           1           0
# 248                 1           0           1
# 118                 1           0           0
# 326                 1           0           1
# 369                 0           0           0

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Predictions

# %%
y_pred_train=lr.predict(X_train)
y_pred_test=lr.predict(X_test)

# %%
y_pred_df=pd.DataFrame({"Actual":y_test,"Expected":y_pred_test})

# %%
y_pred_df
# Out:
#      Actual  Expected
# 626       0         0
# 672       0         0
# 246       0         1
# 173       0         0
# 601       0         0
# ..      ...       ...
# 349       0         0
# 108       0         0
# 318       1         1
# 24        0         0
# 262       0         0
#
# [179 rows x 2 columns]

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score
print("Training_Accuracy_Score : ",accuracy_score(y_train,y_pred_train))
print("\nTesting_Accuracy_Score : ",accuracy_score(y_test,y_pred_test))
# Out:
# Training_Accuracy_Score :  0.824438202247191
#
# Testing_Accuracy_Score :  0.8212290502793296

# %%
from sklearn.metrics import confusion_matrix
print("Training_confusion_matrix : ",confusion_matrix(y_train,y_pred_train))
print("\n\nTesting_confusion_matrix : ",confusion_matrix(y_test,y_pred_test))
# Out:
# Training_confusion_matrix :  [[377  57]
#  [ 68 210]]
#
#
# Testing_confusion_matrix :  [[99 16]
#  [16 48]]

# %%
from sklearn.metrics import precision_score
print("Training_precision_Score : ",precision_score(y_train,y_pred_train))
print("\n\nTesting_precision_Score : ",precision_score(y_test,y_pred_test))
# Out:
# Training_precision_Score :  0.7865168539325843
#
#
# Testing_precision_Score :  0.75

# %%
from sklearn.metrics import recall_score
print("Training_recall_Score : ",recall_score(y_train,y_pred_train))
print("\n\nTesting_recall_Score : ",recall_score(y_test,y_pred_test))
# Out:
# Training_recall_Score :  0.7553956834532374
#
#
# Testing_recall_Score :  0.75

# %%
from sklearn.metrics import f1_score
print("Training_f1_Score : ",f1_score(y_train,y_pred_train))
print("\n\nTesting_f1_Score : ",f1_score(y_test,y_pred_test))
# Out:
# Training_f1_Score :  0.7706422018348624
#
#
# Testing_f1_Score :  0.75

# %%
from sklearn.metrics import classification_report
print("Training_classification_report : ",classification_report(y_train,y_pred_train))
print("\n\nTesting_classification_report : ",classification_report(y_test,y_pred_test))
# Out:
# Training_classification_report :                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       434
#            1       0.79      0.76      0.77       278
#
#     accuracy                           0.82       712
#    macro avg       0.82      0.81      0.81       712
# weighted avg       0.82      0.82      0.82       712
#
#
#
# Testing_classification_report :                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       115
#            1       0.75      0.75      0.75        64
#
#     accuracy                           0.82       179
#    macro avg       0.81      0.81      0.81       179
# weighted avg       0.82      0.82      0.82       179
